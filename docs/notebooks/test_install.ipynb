# %% [markdown]
# ### Installation Tests

# %%
# Check Python version
import sys
print(f"Python version: {sys.version}")
# Out:
# Python version: 3.11.11 | packaged by conda-forge | (main, Mar  3 2025, 20:44:07) [Clang 18.1.8 ]

# %%
# Check pycontrails location
import pycontrails
print(f"Pycontrails location: {pycontrails.__file__}")
# Should show your git directory path
# Out:
# Pycontrails location: /Users/gett613/Library/CloudStorage/OneDrive-PNNL/Documents/GitHub/pycontrails_git/pycontrails/__init__.py

# %%
# Import UPCOM
from pycontrails.models.upcom import UPCOM, UPCOMParams
print("✓ UPCOM imported successfully")
# Out:
# ✓ UPCOM imported successfully

# %%
# Check ERA5 access
from pycontrails.datalib.ecmwf import ERA5
print("✓ ERA5 access available")
# Out:
# ✓ ERA5 access available

# %%
# Quick test
print(f"\nUPCOM docstring preview: {UPCOM.__doc__[:100]}...")
# Out:
# UPCOM docstring preview: Unified Parametric Contrail Model - Grid Analysis.
#
#     This model identifies regions favorable for ...
